# %% [markdown]
# # YBI Foundation
# ### Join Telegram to Get Updates of all Future FREE Bootcamps and Courses
#
# # Multi Category Classification - Wine Type Prediction
# #### Watch Video Tutorial

# %%
# Step 1 : import library
import pandas as pd

# %%
# Step 2 : import data
from sklearn.datasets import load_wine

data = load_wine()
wine = pd.DataFrame(data.data, columns=data.feature_names)
wine['species'] = pd.Series(data.target).map({0: data.target_names[0], 1: data.target_names[1], 2: data.target_names[2]})

# %%
wine.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  od280/od315_of_diluted_wines  proline  species
# 0    14.23        1.71  2.43               15.6      127.0           2.80        3.06                  0.28             2.29             5.64  1.04                          3.92   1065.0  class_0
# 1    13.20        1.78  2.14               11.2      100.0           2.65        2.76                  0.26             1.28             4.38  1.05                          3.40   1050.0  class_0
# 2    13.16        2.36  2.67               18.6      101.0           2.80        3.24                  0.30             2.81             5.68  1.03                          3.17   1185.0  class_0
# 3    14.37        1.95  2.50               16.8      113.0           3.85        3.49                  0.24             2.18             7.80  0.86                          3.45   1480.0  class_0
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   alcohol                        178 non-null    float64
#  1   malic_acid                     178 non-null    float64
#  2   ash                            178 non-null    float64
#  3   alcalinity_of_ash              178 non-null    float64
#  4   magnesium                      178 non-null    float64
#  5   total_phenols                  178 non-null    float64
#  6   flavanoids                     178 non-null    float64
#  7   nonflavanoid_phenols           178 non-null    float64
#  8   proanthocyanins                178 non-null    float64
#  9   color_intensity                178 non-null    float64
#  10  hue                            178 non-null    float64
#  11  od280/od315_of_diluted_wines   178 non-null    float64
# ...

# %%
wine.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity         hue  od280/od315_of_diluted_wines      proline
# count  178.000000  178.000000  178.000000         178.000000  178.000000     178.000000  178.000000            178.000000       178.000000       178.000000  178.000000                    178.000000   178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573       2.295112    2.029270              0.361854         1.590899         5.058090    0.957449                      2.611685   746.893258
# std      0.811827    1.117146    0.274344           3.339564   14.282484       0.625851    0.998859              0.124453         0.572359         2.318286    0.228572                      0.709990   314.907474
# ...

# %%
# Step 3 : define target (y) and features (X)

# %%
wine.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'species'],
#       dtype='object')

# %%
y = wine['species']

# %%
X = wine.drop(['species'],axis=1)

# %% [markdown]
# # Step 4 : train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=2529)

# %%
# check shape of train and test sample
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((124, 13), (54, 13), (124,), (54,))

# %% [markdown]
# # Step 5 : select model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=5000)

# %% [markdown]
# # Step 6 : train or fit model

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
model.intercept_
# Out:
# array([-14.60572965,  20.52831838,  -5.92258873])

# %%
model.coef_
# Out:
# array([[ 0.44768121,  0.50975309,  0.67747821, -0.27425822, -0.0077546 ,
#          0.27690576,  0.75079515,  0.07534447,  0.1932132 ,  0.1342345 ,
#         -0.02208656,  0.63950202,  0.0104334 ],
#        [-0.64468214, -0.83423037, -0.70786531,  0.1714164 , -0.03307305,
#          0.10830442,  0.27631016,  0.01847737,  0.4373138 , -0.94597328,
#          0.29114557, -0.00230934, -0.00740685],
#        [ 0.19700092,  0.32447728,  0.0303871 ,  0.10284183,  0.04082765,
#         -0.38521019, -1.02710531, -0.09382184, -0.630527  ,  0.81173878,
#         -0.26905901, -0.63719268, -0.00302655]])

# %% [markdown]
# # Step 7 : predict model

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array(['class_2', 'class_2', 'class_1', 'class_0', 'class_1', 'class_1',
#        'class_0', 'class_2', 'class_0', 'class_1', 'class_1', 'class_1',
#        'class_2', 'class_0', 'class_2', 'class_0', 'class_2', 'class_2',
#        'class_0', 'class_1', 'class_2', 'class_1', 'class_0', 'class_2',
#        'class_2', 'class_1', 'class_1', 'class_2', 'class_0', 'class_1',
#        'class_1', 'class_0', 'class_1', 'class_0', 'class_1', 'class_1',
#        'class_0', 'class_2', 'class_1', 'class_0', 'class_0', 'class_0',
#        'class_0', 'class_2', 'class_1', 'class_0', 'class_2', 'class_1',
#        'class_0', 'class_1', 'class_0', 'class_2', 'class_2', 'class_2'],
#       dtype=object)

# %% [markdown]
# # Step 8 : model accuracy

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[17,  0,  0],
#        [ 1, 19,  1],
#        [ 0,  0, 16]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9629629629629629

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      class_0       0.94      1.00      0.97        17
#      class_1       1.00      0.90      0.95        21
#      class_2       0.94      1.00      0.97        16
#
#     accuracy                           0.96        54
#    macro avg       0.96      0.97      0.96        54
# weighted avg       0.97      0.96      0.96        54

# %% [markdown]
# ### Don't Forget to Star and Watch on GitHub to Receive Updates
# **Action 1:** ⭐ Star Repository as it makes it easy for you to find it again. You can see all the repositories and topics you have starred by going to your stars page.
#
# **Action 2:** 👁 Watch Repository and get notified of all future updates and activities in this repository.
#
# **Click Here to Visit Fundamental Repository on GitHub**
#
# ---
# ### Don't Forget to Upvote NoteBook on Kaggle and Receive Updates
# **Click Here to Visit Kaggle**
